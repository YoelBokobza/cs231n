# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'CS231n_assignment2'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CS231n_assignment2/cs231n/datasets
# /content/drive/My Drive/CS231n_assignment2

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from Assignment 1. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.   
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 7.696803870986541e-08
# W2 relative error: 1.7087519140575808e-05
# W3 relative error: 2.9508423118300657e-07
# b1 relative error: 4.660094650186831e-09
# b2 relative error: 2.085654124402131e-09
# b3 relative error: 6.598642296022133e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.904542008453064e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 2.1311298702113723e-08
# b1 relative error: 1.1683196894962977e-08
# b2 relative error: 1.7223751746766738e-09
# b3 relative error: 1.3200479211447775e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 2e-2   # Experiment with this!
learning_rate = 1e-2  # Experiment with this!
model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 3.545646
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.117000
# (Epoch 3 / 20) train acc: 0.660000; val_acc: 0.159000
# (Epoch 4 / 20) train acc: 0.620000; val_acc: 0.130000
# (Epoch 5 / 20) train acc: 0.760000; val_acc: 0.185000
# (Iteration 11 / 40) loss: 0.876595
# (Epoch 6 / 20) train acc: 0.820000; val_acc: 0.162000
# (Epoch 7 / 20) train acc: 0.940000; val_acc: 0.173000
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.169000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.171000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.170000
# (Iteration 21 / 40) loss: 0.070086
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.170000
# (Epoch 12 / 20) train acc: 0.980000; val_acc: 0.160000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.194000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.179000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.179000
# (Iteration 31 / 40) loss: 0.014441
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.172000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.171000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.174000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.170000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.174000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 1e-3  # Experiment with this!
weight_scale = 1e-1   # Experiment with this!
model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 104.406490
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.118000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.580000; val_acc: 0.091000
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.880000; val_acc: 0.095000
# (Iteration 11 / 40) loss: 0.012642
# (Epoch 6 / 20) train acc: 0.920000; val_acc: 0.100000
# (Epoch 7 / 20) train acc: 0.860000; val_acc: 0.104000
# (Epoch 8 / 20) train acc: 0.960000; val_acc: 0.115000
# (Epoch 9 / 20) train acc: 0.960000; val_acc: 0.110000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.115000
# (Iteration 21 / 40) loss: 0.007002
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.115000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.114000
# (Iteration 31 / 40) loss: 0.000065
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.114000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# Deeper networks are more sensitive to weights initialization. The reason is that if the weights are too large, as the data flows through the network, the values in deeper layers can explode, and when the weights are too small, the values in deeper layers will be close to zero. Thus, while applying backprop, the gradients will be close to zero (vanishing gradient).

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")
    
for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.741599
# (Epoch 0 / 5) train acc: 0.091000; val_acc: 0.115000
# (Iteration 11 / 200) loss: 2.314941
# (Iteration 21 / 200) loss: 2.232328
# (Iteration 31 / 200) loss: 2.139264
# (Epoch 1 / 5) train acc: 0.249000; val_acc: 0.220000
# (Iteration 41 / 200) loss: 2.079357
# (Iteration 51 / 200) loss: 1.962110
# (Iteration 61 / 200) loss: 1.971500
# (Iteration 71 / 200) loss: 2.087241
# (Epoch 2 / 5) train acc: 0.317000; val_acc: 0.265000
# (Iteration 81 / 200) loss: 1.886418
# (Iteration 91 / 200) loss: 1.949667
# (Iteration 101 / 200) loss: 1.697450
# (Iteration 111 / 200) loss: 1.959588
# (Epoch 3 / 5) train acc: 0.325000; val_acc: 0.286000
# (Iteration 121 / 200) loss: 1.755608
# (Iteration 131 / 200) loss: 1.996791
# (Iteration 141 / 200) loss: 1.876664
# (Iteration 151 / 200) loss: 1.890848
# (Epoch 4 / 5) train acc: 0.374000; val_acc: 0.315000
# (Iteration 161 / 200) loss: 1.750537
# (Iteration 171 / 200) loss: 1.969991
# (Iteration 181 / 200) loss: 1.864466
# (Iteration 191 / 200) loss: 1.812410
# (Epoch 5 / 5) train acc: 0.390000; val_acc: 0.319000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 3.079422
# (Epoch 0 / 5) train acc: 0.073000; val_acc: 0.074000
# (Iteration 11 / 200) loss: 2.232500
# (Iteration 21 / 200) loss: 2.061582
# (Iteration 31 / 200) loss: 1.911658
# (Epoch 1 / 5) train acc: 0.326000; val_acc: 0.262000
# (Iteration 41 / 200) loss: 1.781161
# (Iteration 51 / 200) loss: 1.863305
# (Iteration 61 / 200) loss: 1.966865
# (Iteration 71 / 200) loss: 1.595720
# (Epoch 2 / 5) train acc: 0.375000; val_acc: 0.309000
# (Iteration 81 / 200) loss: 1.683251
# (Iteration 91 / 200) loss: 1.699018
# (Iteration 101 / 200) loss: 1.755739
# (Iteration 111 / 200) loss: 1.658595
# (Epoch 3 / 5) train acc: 0.414000; val_acc: 0.315000
# (Iteration 121 / 200) loss: 1.538944
# (Iteration 131 / 200) loss: 1.331760
# (Iteration 141 / 200) loss: 1.441264
# (Iteration 151 / 200) loss: 1.344388
# (Epoch 4 / 5) train acc: 0.442000; val_acc: 0.335000
# (Iteration 161 / 200) loss: 1.521008
# (Iteration 171 / 200) loss: 1.677570
# (Iteration 181 / 200) loss: 1.354759
# (Iteration 191 / 200) loss: 1.469924
# (Epoch 5 / 5) train acc: 0.516000; val_acc: 0.327000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.502645229894295e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  0.0015218451757856217
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()
    
fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")
    
for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 2.829552
# (Epoch 0 / 5) train acc: 0.111000; val_acc: 0.100000
# (Iteration 11 / 200) loss: 2.067182
# (Iteration 21 / 200) loss: 1.959744
# (Iteration 31 / 200) loss: 1.991639
# (Epoch 1 / 5) train acc: 0.350000; val_acc: 0.301000
# (Iteration 41 / 200) loss: 1.840553
# (Iteration 51 / 200) loss: 1.793442
# (Iteration 61 / 200) loss: 1.740824
# (Iteration 71 / 200) loss: 1.567941
# (Epoch 2 / 5) train acc: 0.386000; val_acc: 0.321000
# (Iteration 81 / 200) loss: 1.780444
# (Iteration 91 / 200) loss: 1.650556
# (Iteration 101 / 200) loss: 1.759619
# (Iteration 111 / 200) loss: 1.772697
# (Epoch 3 / 5) train acc: 0.454000; val_acc: 0.348000
# (Iteration 121 / 200) loss: 1.321688
# (Iteration 131 / 200) loss: 1.345077
# (Iteration 141 / 200) loss: 1.486090
# (Iteration 151 / 200) loss: 1.368359
# (Epoch 4 / 5) train acc: 0.532000; val_acc: 0.367000
# (Iteration 161 / 200) loss: 1.204133
# (Iteration 171 / 200) loss: 1.150766
# (Iteration 181 / 200) loss: 1.170122
# (Iteration 191 / 200) loss: 1.359729
# (Epoch 5 / 5) train acc: 0.565000; val_acc: 0.373000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.663155
# (Epoch 0 / 5) train acc: 0.132000; val_acc: 0.105000
# (Iteration 11 / 200) loss: 2.065687
# (Iteration 21 / 200) loss: 1.870181
# (Iteration 31 / 200) loss: 2.109196
# (Epoch 1 / 5) train acc: 0.355000; val_acc: 0.296000
# (Iteration 41 / 200) loss: 1.869855
# (Iteration 51 / 200) loss: 1.887633
# (Iteration 61 / 200) loss: 1.735987
# (Iteration 71 / 200) loss: 1.783794
# (Epoch 2 / 5) train acc: 0.404000; val_acc: 0.328000
# (Iteration 81 / 200) loss: 1.590807
# (Iteration 91 / 200) loss: 1.582309
# (Iteration 101 / 200) loss: 1.551323
# (Iteration 111 / 200) loss: 1.660129
# (Epoch 3 / 5) train acc: 0.489000; val_acc: 0.336000
# (Iteration 121 / 200) loss: 1.730901
# (Iteration 131 / 200) loss: 1.543110
# (Iteration 141 / 200) loss: 1.497886
# (Iteration 151 / 200) loss: 1.419915
# (Epoch 4 / 5) train acc: 0.495000; val_acc: 0.343000
# (Iteration 161 / 200) loss: 1.581374
# (Iteration 171 / 200) loss: 1.415457
# (Iteration 181 / 200) loss: 1.516212
# (Iteration 191 / 200) loss: 1.361360
# (Epoch 5 / 5) train acc: 0.564000; val_acc: 0.364000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# In AdaGrad, the value of the cache increases at every time step. Then, after many steps, the cache values are very large, hence 1 over these values produce small values.
# In Adam, and  RMSProp, we are updating the squared gradient using moving average.

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_val_acc = -1
best_results = {'learning_rate':None, 'weight_scale':None}
best_model = None
hidden_sizes = [100, 100]
learning_rates = [5e-6, 1e-5, 1e-4]
weight_scale = [1e-4, 1e-3]
fig, axes = plt.subplots(3, 1, figsize=(15, 15))
for lr in learning_rates:
  for ws in weight_scale:
    model = FullyConnectedNet(hidden_sizes, weight_scale=ws)
    solver = Solver(model,
                    data,
                    num_epochs=5,
                    batch_size=200,
                    update_rule='adam',
                    optim_config={'learning_rate': lr},
                    verbose=True)
    solver.train()


    axes[0].set_title('Training loss')
    axes[0].set_xlabel('Iteration')
    axes[1].set_title('Training accuracy')
    axes[1].set_xlabel('Epoch')
    axes[2].set_title('Validation accuracy')
    axes[2].set_xlabel('Epoch')

    axes[0].plot(solver.loss_history, label='lr={}'.format(lr) + ' w_scale={}'.format(ws))
    axes[1].plot(solver.train_acc_history, label='lr={}'.format(lr) + ' w_scale={}'.format(ws))
    axes[2].plot(solver.val_acc_history, label='lr={}'.format(lr) + ' w_scale={}'.format(ws))
    
    
    val_acc = solver.check_accuracy(data['X_val'], data['y_val'])
    if val_acc > best_val_acc:
      best_results['learning_rate'] = lr
      best_results['batch_size'] = bs
      best_val_acc = val_acc
      best_model = solver

for ax in axes:
    ax.legend(loc='best')
    ax.grid()

plt.show()

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.145000; val_acc: 0.147000
# (Iteration 11 / 1225) loss: 2.302579
# (Iteration 21 / 1225) loss: 2.302567
# (Iteration 31 / 1225) loss: 2.302463
# (Iteration 41 / 1225) loss: 2.302138
# (Iteration 51 / 1225) loss: 2.301568
# (Iteration 61 / 1225) loss: 2.299918
# (Iteration 71 / 1225) loss: 2.299764
# (Iteration 81 / 1225) loss: 2.292055
# (Iteration 91 / 1225) loss: 2.289568
# (Iteration 101 / 1225) loss: 2.278653
# (Iteration 111 / 1225) loss: 2.282503
# (Iteration 121 / 1225) loss: 2.260163
# (Iteration 131 / 1225) loss: 2.254637
# (Iteration 141 / 1225) loss: 2.228248
# (Iteration 151 / 1225) loss: 2.220713
# (Iteration 161 / 1225) loss: 2.205216
# (Iteration 171 / 1225) loss: 2.183561
# (Iteration 181 / 1225) loss: 2.212798
# (Iteration 191 / 1225) loss: 2.176274
# (Iteration 201 / 1225) loss: 2.176559
# (Iteration 211 / 1225) loss: 2.183142
# (Iteration 221 / 1225) loss: 2.185909
# (Iteration 231 / 1225) loss: 2.147759
# (Iteration 241 / 1225) loss: 2.193210
# (Epoch 1 / 5) train acc: 0.152000; val_acc: 0.177000
# (Iteration 251 / 1225) loss: 2.113063
# (Iteration 261 / 1225) loss: 2.157050
# (Iteration 271 / 1225) loss: 2.122903
# (Iteration 281 / 1225) loss: 2.137435
# (Iteration 291 / 1225) loss: 2.151023
# (Iteration 301 / 1225) loss: 2.085340
# (Iteration 311 / 1225) loss: 2.109304
# (Iteration 321 / 1225) loss: 2.074411
# (Iteration 331 / 1225) loss: 2.107091
# (Iteration 341 / 1225) loss: 2.056561
# (Iteration 351 / 1225) loss: 2.073707
# (Iteration 361 / 1225) loss: 2.108709
# (Iteration 371 / 1225) loss: 2.122258
# (Iteration 381 / 1225) loss: 2.120638
# (Iteration 391 / 1225) loss: 2.123187
# (Iteration 401 / 1225) loss: 2.108605
# (Iteration 411 / 1225) loss: 2.090456
# (Iteration 421 / 1225) loss: 2.143755
# (Iteration 431 / 1225) loss: 2.038488
# (Iteration 441 / 1225) loss: 2.097078
# (Iteration 451 / 1225) loss: 2.081535
# (Iteration 461 / 1225) loss: 2.134810
# (Iteration 471 / 1225) loss: 2.118354
# (Iteration 481 / 1225) loss: 2.134257
# (Epoch 2 / 5) train acc: 0.191000; val_acc: 0.190000
# (Iteration 491 / 1225) loss: 2.052077
# (Iteration 501 / 1225) loss: 2.097772
# (Iteration 511 / 1225) loss: 2.108520
# (Iteration 521 / 1225) loss: 2.131441
# (Iteration 531 / 1225) loss: 2.077997
# (Iteration 541 / 1225) loss: 2.067415
# (Iteration 551 / 1225) loss: 2.068506
# (Iteration 561 / 1225) loss: 2.067123
# (Iteration 571 / 1225) loss: 2.081687
# (Iteration 581 / 1225) loss: 2.036817
# (Iteration 591 / 1225) loss: 2.079159
# (Iteration 601 / 1225) loss: 2.084218
# (Iteration 611 / 1225) loss: 2.065514
# (Iteration 621 / 1225) loss: 2.059584
# (Iteration 631 / 1225) loss: 2.040343
# (Iteration 641 / 1225) loss: 2.141359
# (Iteration 651 / 1225) loss: 2.062875
# (Iteration 661 / 1225) loss: 1.998488
# (Iteration 671 / 1225) loss: 2.020405
# (Iteration 681 / 1225) loss: 2.062511
# (Iteration 691 / 1225) loss: 2.104156
# (Iteration 701 / 1225) loss: 2.085523
# (Iteration 711 / 1225) loss: 2.158573
# (Iteration 721 / 1225) loss: 1.986675
# (Iteration 731 / 1225) loss: 2.026876
# (Epoch 3 / 5) train acc: 0.169000; val_acc: 0.188000
# (Iteration 741 / 1225) loss: 2.079432
# (Iteration 751 / 1225) loss: 2.019759
# (Iteration 761 / 1225) loss: 2.039854
# (Iteration 771 / 1225) loss: 2.088838
# (Iteration 781 / 1225) loss: 2.081682
# (Iteration 791 / 1225) loss: 2.006901
# (Iteration 801 / 1225) loss: 2.053009
# (Iteration 811 / 1225) loss: 1.993489
# (Iteration 821 / 1225) loss: 2.052490
# (Iteration 831 / 1225) loss: 2.046796
# (Iteration 841 / 1225) loss: 2.065518
# (Iteration 851 / 1225) loss: 2.045714
# (Iteration 861 / 1225) loss: 2.123452
# (Iteration 871 / 1225) loss: 2.027461
# (Iteration 881 / 1225) loss: 2.022100
# (Iteration 891 / 1225) loss: 1.991602
# (Iteration 901 / 1225) loss: 2.037272
# (Iteration 911 / 1225) loss: 2.084039
# (Iteration 921 / 1225) loss: 1.962199
# (Iteration 931 / 1225) loss: 2.066288
# (Iteration 941 / 1225) loss: 2.131022
# (Iteration 951 / 1225) loss: 2.032032
# (Iteration 961 / 1225) loss: 2.106570
# (Iteration 971 / 1225) loss: 2.029764
# (Epoch 4 / 5) train acc: 0.191000; val_acc: 0.200000
# (Iteration 981 / 1225) loss: 2.017567
# (Iteration 991 / 1225) loss: 2.106372
# (Iteration 1001 / 1225) loss: 2.097152
# (Iteration 1011 / 1225) loss: 2.083257
# (Iteration 1021 / 1225) loss: 2.039513
# (Iteration 1031 / 1225) loss: 2.035607
# (Iteration 1041 / 1225) loss: 2.004778
# (Iteration 1051 / 1225) loss: 2.073142
# (Iteration 1061 / 1225) loss: 2.027439
# (Iteration 1071 / 1225) loss: 2.100993
# (Iteration 1081 / 1225) loss: 2.050805
# (Iteration 1091 / 1225) loss: 1.955425
# (Iteration 1101 / 1225) loss: 2.033890
# (Iteration 1111 / 1225) loss: 2.124489
# (Iteration 1121 / 1225) loss: 2.071513
# (Iteration 1131 / 1225) loss: 2.054682
# (Iteration 1141 / 1225) loss: 2.109757
# (Iteration 1151 / 1225) loss: 2.058329
# (Iteration 1161 / 1225) loss: 2.030500
# (Iteration 1171 / 1225) loss: 2.005051
# (Iteration 1181 / 1225) loss: 2.010142
# (Iteration 1191 / 1225) loss: 2.044377
# (Iteration 1201 / 1225) loss: 2.030103
# (Iteration 1211 / 1225) loss: 2.059215
# (Iteration 1221 / 1225) loss: 2.006741
# (Epoch 5 / 5) train acc: 0.209000; val_acc: 0.206000
# (Iteration 1 / 1225) loss: 2.302597
# (Epoch 0 / 5) train acc: 0.122000; val_acc: 0.111000
# (Iteration 11 / 1225) loss: 2.302455
# (Iteration 21 / 1225) loss: 2.302236
# (Iteration 31 / 1225) loss: 2.302059
# (Iteration 41 / 1225) loss: 2.301736
# (Iteration 51 / 1225) loss: 2.300967
# (Iteration 61 / 1225) loss: 2.299457
# (Iteration 71 / 1225) loss: 2.298514
# (Iteration 81 / 1225) loss: 2.295800
# (Iteration 91 / 1225) loss: 2.295678
# (Iteration 101 / 1225) loss: 2.290677
# (Iteration 111 / 1225) loss: 2.288739
# (Iteration 121 / 1225) loss: 2.283096
# (Iteration 131 / 1225) loss: 2.270421
# (Iteration 141 / 1225) loss: 2.247114
# (Iteration 151 / 1225) loss: 2.242095
# (Iteration 161 / 1225) loss: 2.226775
# (Iteration 171 / 1225) loss: 2.228545
# (Iteration 181 / 1225) loss: 2.202466
# (Iteration 191 / 1225) loss: 2.210636
# (Iteration 201 / 1225) loss: 2.217000
# (Iteration 211 / 1225) loss: 2.170917
# (Iteration 221 / 1225) loss: 2.181331
# (Iteration 231 / 1225) loss: 2.113980
# (Iteration 241 / 1225) loss: 2.175022
# (Epoch 1 / 5) train acc: 0.213000; val_acc: 0.229000
# (Iteration 251 / 1225) loss: 2.093537
# (Iteration 261 / 1225) loss: 2.071304
# (Iteration 271 / 1225) loss: 2.156494
# (Iteration 281 / 1225) loss: 2.135223
# (Iteration 291 / 1225) loss: 2.048379
# (Iteration 301 / 1225) loss: 2.142531
# (Iteration 311 / 1225) loss: 2.097217
# (Iteration 321 / 1225) loss: 2.041931
# (Iteration 331 / 1225) loss: 2.076669
# (Iteration 341 / 1225) loss: 2.044336
# (Iteration 351 / 1225) loss: 2.135090
# (Iteration 361 / 1225) loss: 2.103127
# (Iteration 371 / 1225) loss: 2.051410
# (Iteration 381 / 1225) loss: 2.085292
# (Iteration 391 / 1225) loss: 2.041753
# (Iteration 401 / 1225) loss: 2.081382
# (Iteration 411 / 1225) loss: 2.023916
# (Iteration 421 / 1225) loss: 2.035651
# (Iteration 431 / 1225) loss: 1.996725
# (Iteration 441 / 1225) loss: 2.064211
# (Iteration 451 / 1225) loss: 2.052283
# (Iteration 461 / 1225) loss: 2.055404
# (Iteration 471 / 1225) loss: 2.078688
# (Iteration 481 / 1225) loss: 2.071615
# (Epoch 2 / 5) train acc: 0.265000; val_acc: 0.269000
# (Iteration 491 / 1225) loss: 2.025564
# (Iteration 501 / 1225) loss: 2.046147
# (Iteration 511 / 1225) loss: 2.042080
# (Iteration 521 / 1225) loss: 1.992584
# (Iteration 531 / 1225) loss: 2.086169
# (Iteration 541 / 1225) loss: 2.026778
# (Iteration 551 / 1225) loss: 2.065203
# (Iteration 561 / 1225) loss: 1.948597
# (Iteration 571 / 1225) loss: 2.016151
# (Iteration 581 / 1225) loss: 2.067982
# (Iteration 591 / 1225) loss: 1.866948
# (Iteration 601 / 1225) loss: 1.957003
# (Iteration 611 / 1225) loss: 2.024710
# (Iteration 621 / 1225) loss: 1.940738
# (Iteration 631 / 1225) loss: 1.978294
# (Iteration 641 / 1225) loss: 1.937372
# (Iteration 651 / 1225) loss: 2.013659
# (Iteration 661 / 1225) loss: 2.050755
# (Iteration 671 / 1225) loss: 1.987151
# (Iteration 681 / 1225) loss: 1.913618
# (Iteration 691 / 1225) loss: 1.846994
# (Iteration 701 / 1225) loss: 1.978346
# (Iteration 711 / 1225) loss: 1.961423
# (Iteration 721 / 1225) loss: 1.938417
# (Iteration 731 / 1225) loss: 1.930845
# (Epoch 3 / 5) train acc: 0.298000; val_acc: 0.269000
# (Iteration 741 / 1225) loss: 1.975822
# (Iteration 751 / 1225) loss: 1.976766
# (Iteration 761 / 1225) loss: 1.986945
# (Iteration 771 / 1225) loss: 1.939998
# (Iteration 781 / 1225) loss: 1.924422
# (Iteration 791 / 1225) loss: 1.941986
# (Iteration 801 / 1225) loss: 1.927337
# (Iteration 811 / 1225) loss: 1.911238
# (Iteration 821 / 1225) loss: 1.967202
# (Iteration 831 / 1225) loss: 1.895296
# (Iteration 841 / 1225) loss: 1.916191
# (Iteration 851 / 1225) loss: 1.956776
# (Iteration 861 / 1225) loss: 1.929773
# (Iteration 871 / 1225) loss: 1.972121
# (Iteration 881 / 1225) loss: 1.877650
# (Iteration 891 / 1225) loss: 1.926686
# (Iteration 901 / 1225) loss: 1.934066
# (Iteration 911 / 1225) loss: 1.824387
# (Iteration 921 / 1225) loss: 1.856171
# (Iteration 931 / 1225) loss: 1.900779
# (Iteration 941 / 1225) loss: 1.913284
# (Iteration 951 / 1225) loss: 1.957859
# (Iteration 961 / 1225) loss: 1.941270
# (Iteration 971 / 1225) loss: 1.861519
# (Epoch 4 / 5) train acc: 0.312000; val_acc: 0.293000
# (Iteration 981 / 1225) loss: 1.950116
# (Iteration 991 / 1225) loss: 1.893653
# (Iteration 1001 / 1225) loss: 1.872126
# (Iteration 1011 / 1225) loss: 1.824291
# (Iteration 1021 / 1225) loss: 1.930994
# (Iteration 1031 / 1225) loss: 1.944658
# (Iteration 1041 / 1225) loss: 1.860415
# (Iteration 1051 / 1225) loss: 1.934532
# (Iteration 1061 / 1225) loss: 1.906787
# (Iteration 1071 / 1225) loss: 1.876395
# (Iteration 1081 / 1225) loss: 1.945314
# (Iteration 1091 / 1225) loss: 1.858308
# (Iteration 1101 / 1225) loss: 1.909204
# (Iteration 1111 / 1225) loss: 1.955272
# (Iteration 1121 / 1225) loss: 1.848714
# (Iteration 1131 / 1225) loss: 1.910349
# (Iteration 1141 / 1225) loss: 1.928418
# (Iteration 1151 / 1225) loss: 1.841194
# (Iteration 1161 / 1225) loss: 1.942791
# (Iteration 1171 / 1225) loss: 1.919227
# (Iteration 1181 / 1225) loss: 1.805950
# (Iteration 1191 / 1225) loss: 1.819186
# (Iteration 1201 / 1225) loss: 1.849121
# (Iteration 1211 / 1225) loss: 1.948148
# (Iteration 1221 / 1225) loss: 1.784366
# (Epoch 5 / 5) train acc: 0.298000; val_acc: 0.318000
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.149000; val_acc: 0.171000
# (Iteration 11 / 1225) loss: 2.302562
# (Iteration 21 / 1225) loss: 2.302335
# (Iteration 31 / 1225) loss: 2.301644
# (Iteration 41 / 1225) loss: 2.298988
# (Iteration 51 / 1225) loss: 2.291626
# (Iteration 61 / 1225) loss: 2.281661
# (Iteration 71 / 1225) loss: 2.268758
# (Iteration 81 / 1225) loss: 2.239850
# (Iteration 91 / 1225) loss: 2.200470
# (Iteration 101 / 1225) loss: 2.144137
# (Iteration 111 / 1225) loss: 2.152696
# (Iteration 121 / 1225) loss: 2.134824
# (Iteration 131 / 1225) loss: 2.214169
# (Iteration 141 / 1225) loss: 2.167481
# (Iteration 151 / 1225) loss: 2.140066
# (Iteration 161 / 1225) loss: 2.111691
# (Iteration 171 / 1225) loss: 2.166983
# (Iteration 181 / 1225) loss: 2.090441
# (Iteration 191 / 1225) loss: 2.111700
# (Iteration 201 / 1225) loss: 2.111054
# (Iteration 211 / 1225) loss: 2.067154
# (Iteration 221 / 1225) loss: 2.088299
# (Iteration 231 / 1225) loss: 2.088544
# (Iteration 241 / 1225) loss: 2.092103
# (Epoch 1 / 5) train acc: 0.182000; val_acc: 0.188000
# (Iteration 251 / 1225) loss: 2.078311
# (Iteration 261 / 1225) loss: 2.062610
# (Iteration 271 / 1225) loss: 2.076392
# (Iteration 281 / 1225) loss: 2.081315
# (Iteration 291 / 1225) loss: 2.017612
# (Iteration 301 / 1225) loss: 2.076587
# (Iteration 311 / 1225) loss: 2.115848
# (Iteration 321 / 1225) loss: 2.025209
# (Iteration 331 / 1225) loss: 2.061925
# (Iteration 341 / 1225) loss: 2.065529
# (Iteration 351 / 1225) loss: 2.129638
# (Iteration 361 / 1225) loss: 2.037549
# (Iteration 371 / 1225) loss: 2.084990
# (Iteration 381 / 1225) loss: 2.006931
# (Iteration 391 / 1225) loss: 2.075438
# (Iteration 401 / 1225) loss: 2.042703
# (Iteration 411 / 1225) loss: 2.024512
# (Iteration 421 / 1225) loss: 2.043148
# (Iteration 431 / 1225) loss: 2.066403
# (Iteration 441 / 1225) loss: 2.078223
# (Iteration 451 / 1225) loss: 2.083153
# (Iteration 461 / 1225) loss: 1.995684
# (Iteration 471 / 1225) loss: 2.085268
# (Iteration 481 / 1225) loss: 2.085165
# (Epoch 2 / 5) train acc: 0.202000; val_acc: 0.194000
# (Iteration 491 / 1225) loss: 2.070298
# (Iteration 501 / 1225) loss: 2.015821
# (Iteration 511 / 1225) loss: 2.022816
# (Iteration 521 / 1225) loss: 2.051980
# (Iteration 531 / 1225) loss: 2.041668
# (Iteration 541 / 1225) loss: 2.011932
# (Iteration 551 / 1225) loss: 2.020010
# (Iteration 561 / 1225) loss: 1.984681
# (Iteration 571 / 1225) loss: 2.013737
# (Iteration 581 / 1225) loss: 2.067408
# (Iteration 591 / 1225) loss: 1.972006
# (Iteration 601 / 1225) loss: 2.045994
# (Iteration 611 / 1225) loss: 2.041381
# (Iteration 621 / 1225) loss: 1.974871
# (Iteration 631 / 1225) loss: 2.065118
# (Iteration 641 / 1225) loss: 2.044883
# (Iteration 651 / 1225) loss: 1.979758
# (Iteration 661 / 1225) loss: 1.987340
# (Iteration 671 / 1225) loss: 1.986484
# (Iteration 681 / 1225) loss: 2.020029
# (Iteration 691 / 1225) loss: 2.026562
# (Iteration 701 / 1225) loss: 2.045867
# (Iteration 711 / 1225) loss: 1.958940
# (Iteration 721 / 1225) loss: 2.033300
# (Iteration 731 / 1225) loss: 1.972066
# (Epoch 3 / 5) train acc: 0.225000; val_acc: 0.243000
# (Iteration 741 / 1225) loss: 1.970311
# (Iteration 751 / 1225) loss: 2.025369
# (Iteration 761 / 1225) loss: 2.037026
# (Iteration 771 / 1225) loss: 1.881288
# (Iteration 781 / 1225) loss: 1.929416
# (Iteration 791 / 1225) loss: 1.955948
# (Iteration 801 / 1225) loss: 1.997344
# (Iteration 811 / 1225) loss: 1.975931
# (Iteration 821 / 1225) loss: 1.915479
# (Iteration 831 / 1225) loss: 1.905434
# (Iteration 841 / 1225) loss: 1.998569
# (Iteration 851 / 1225) loss: 1.966439
# (Iteration 861 / 1225) loss: 1.897667
# (Iteration 871 / 1225) loss: 1.934480
# (Iteration 881 / 1225) loss: 1.962464
# (Iteration 891 / 1225) loss: 1.912582
# (Iteration 901 / 1225) loss: 1.986879
# (Iteration 911 / 1225) loss: 1.852053
# (Iteration 921 / 1225) loss: 1.911396
# (Iteration 931 / 1225) loss: 1.961016
# (Iteration 941 / 1225) loss: 1.831195
# (Iteration 951 / 1225) loss: 1.876993
# (Iteration 961 / 1225) loss: 2.009536
# (Iteration 971 / 1225) loss: 1.884529
# (Epoch 4 / 5) train acc: 0.266000; val_acc: 0.250000
# (Iteration 981 / 1225) loss: 1.937862
# (Iteration 991 / 1225) loss: 1.850591
# (Iteration 1001 / 1225) loss: 1.889012
# (Iteration 1011 / 1225) loss: 1.867977
# (Iteration 1021 / 1225) loss: 1.925703
# (Iteration 1031 / 1225) loss: 1.907590
# (Iteration 1041 / 1225) loss: 1.944944
# (Iteration 1051 / 1225) loss: 1.881983
# (Iteration 1061 / 1225) loss: 1.969144
# (Iteration 1071 / 1225) loss: 1.942065
# (Iteration 1081 / 1225) loss: 1.823908
# (Iteration 1091 / 1225) loss: 1.926539
# (Iteration 1101 / 1225) loss: 1.903220
# (Iteration 1111 / 1225) loss: 1.918605
# (Iteration 1121 / 1225) loss: 1.893410
# (Iteration 1131 / 1225) loss: 1.972354
# (Iteration 1141 / 1225) loss: 1.860386
# (Iteration 1151 / 1225) loss: 1.880111
# (Iteration 1161 / 1225) loss: 1.940268
# (Iteration 1171 / 1225) loss: 1.843914
# (Iteration 1181 / 1225) loss: 1.905339
# (Iteration 1191 / 1225) loss: 1.946698
# (Iteration 1201 / 1225) loss: 1.819002
# (Iteration 1211 / 1225) loss: 1.795561
# (Iteration 1221 / 1225) loss: 1.844106
# (Epoch 5 / 5) train acc: 0.294000; val_acc: 0.293000
# (Iteration 1 / 1225) loss: 2.302573
# (Epoch 0 / 5) train acc: 0.105000; val_acc: 0.110000
# (Iteration 11 / 1225) loss: 2.302310
# (Iteration 21 / 1225) loss: 2.301640
# (Iteration 31 / 1225) loss: 2.300352
# (Iteration 41 / 1225) loss: 2.298379
# (Iteration 51 / 1225) loss: 2.291366
# (Iteration 61 / 1225) loss: 2.286056
# (Iteration 71 / 1225) loss: 2.271321
# (Iteration 81 / 1225) loss: 2.257449
# (Iteration 91 / 1225) loss: 2.243866
# (Iteration 101 / 1225) loss: 2.226656
# (Iteration 111 / 1225) loss: 2.177352
# (Iteration 121 / 1225) loss: 2.121408
# (Iteration 131 / 1225) loss: 2.174242
# (Iteration 141 / 1225) loss: 2.146993
# (Iteration 151 / 1225) loss: 2.107913
# (Iteration 161 / 1225) loss: 2.122990
# (Iteration 171 / 1225) loss: 2.147619
# (Iteration 181 / 1225) loss: 2.071385
# (Iteration 191 / 1225) loss: 2.067662
# (Iteration 201 / 1225) loss: 2.099160
# (Iteration 211 / 1225) loss: 2.050451
# (Iteration 221 / 1225) loss: 2.044477
# (Iteration 231 / 1225) loss: 2.034072
# (Iteration 241 / 1225) loss: 2.022154
# (Epoch 1 / 5) train acc: 0.241000; val_acc: 0.247000
# (Iteration 251 / 1225) loss: 1.924955
# (Iteration 261 / 1225) loss: 2.056999
# (Iteration 271 / 1225) loss: 1.975336
# (Iteration 281 / 1225) loss: 1.990911
# (Iteration 291 / 1225) loss: 1.980742
# (Iteration 301 / 1225) loss: 2.009625
# (Iteration 311 / 1225) loss: 1.973012
# (Iteration 321 / 1225) loss: 1.983362
# (Iteration 331 / 1225) loss: 1.980417
# (Iteration 341 / 1225) loss: 1.969612
# (Iteration 351 / 1225) loss: 2.030760
# (Iteration 361 / 1225) loss: 1.999761
# (Iteration 371 / 1225) loss: 1.991468
# (Iteration 381 / 1225) loss: 2.012687
# (Iteration 391 / 1225) loss: 1.976858
# (Iteration 401 / 1225) loss: 1.979643
# (Iteration 411 / 1225) loss: 1.955627
# (Iteration 421 / 1225) loss: 1.998883
# (Iteration 431 / 1225) loss: 2.065770
# (Iteration 441 / 1225) loss: 1.898454
# (Iteration 451 / 1225) loss: 1.948915
# (Iteration 461 / 1225) loss: 1.977125
# (Iteration 471 / 1225) loss: 1.957519
# (Iteration 481 / 1225) loss: 1.951772
# (Epoch 2 / 5) train acc: 0.267000; val_acc: 0.275000
# (Iteration 491 / 1225) loss: 1.946080
# (Iteration 501 / 1225) loss: 1.895283
# (Iteration 511 / 1225) loss: 1.873260
# (Iteration 521 / 1225) loss: 1.982483
# (Iteration 531 / 1225) loss: 2.054626
# (Iteration 541 / 1225) loss: 1.887298
# (Iteration 551 / 1225) loss: 1.908423
# (Iteration 561 / 1225) loss: 1.902190
# (Iteration 571 / 1225) loss: 1.884562
# (Iteration 581 / 1225) loss: 1.933144
# (Iteration 591 / 1225) loss: 1.869708
# (Iteration 601 / 1225) loss: 1.872815
# (Iteration 611 / 1225) loss: 1.964464
# (Iteration 621 / 1225) loss: 1.940148
# (Iteration 631 / 1225) loss: 1.898059
# (Iteration 641 / 1225) loss: 1.859848
# (Iteration 651 / 1225) loss: 1.972579
# (Iteration 661 / 1225) loss: 1.897668
# (Iteration 671 / 1225) loss: 1.904131
# (Iteration 681 / 1225) loss: 1.898485
# (Iteration 691 / 1225) loss: 1.956526
# (Iteration 701 / 1225) loss: 1.961008
# (Iteration 711 / 1225) loss: 1.902340
# (Iteration 721 / 1225) loss: 1.819395
# (Iteration 731 / 1225) loss: 1.807389
# (Epoch 3 / 5) train acc: 0.299000; val_acc: 0.326000
# (Iteration 741 / 1225) loss: 1.825287
# (Iteration 751 / 1225) loss: 1.794569
# (Iteration 761 / 1225) loss: 1.869093
# (Iteration 771 / 1225) loss: 1.771284
# (Iteration 781 / 1225) loss: 1.962187
# (Iteration 791 / 1225) loss: 1.872315
# (Iteration 801 / 1225) loss: 1.858619
# (Iteration 811 / 1225) loss: 1.808627
# (Iteration 821 / 1225) loss: 1.903139
# (Iteration 831 / 1225) loss: 1.794845
# (Iteration 841 / 1225) loss: 1.976192
# (Iteration 851 / 1225) loss: 1.808253
# (Iteration 861 / 1225) loss: 1.825338
# (Iteration 871 / 1225) loss: 1.779247
# (Iteration 881 / 1225) loss: 1.846792
# (Iteration 891 / 1225) loss: 1.923621
# (Iteration 901 / 1225) loss: 1.864394
# (Iteration 911 / 1225) loss: 1.866717
# (Iteration 921 / 1225) loss: 1.921998
# (Iteration 931 / 1225) loss: 1.882679
# (Iteration 941 / 1225) loss: 1.822915
# (Iteration 951 / 1225) loss: 1.849398
# (Iteration 961 / 1225) loss: 1.794859
# (Iteration 971 / 1225) loss: 1.854481
# (Epoch 4 / 5) train acc: 0.323000; val_acc: 0.341000
# (Iteration 981 / 1225) loss: 1.790132
# (Iteration 991 / 1225) loss: 1.750953
# (Iteration 1001 / 1225) loss: 1.666595
# (Iteration 1011 / 1225) loss: 1.896101
# (Iteration 1021 / 1225) loss: 1.831717
# (Iteration 1031 / 1225) loss: 1.635578
# (Iteration 1041 / 1225) loss: 1.809951
# (Iteration 1051 / 1225) loss: 1.794763
# (Iteration 1061 / 1225) loss: 1.832920
# (Iteration 1071 / 1225) loss: 1.680584
# (Iteration 1081 / 1225) loss: 1.876984
# (Iteration 1091 / 1225) loss: 1.820768
# (Iteration 1101 / 1225) loss: 1.838261
# (Iteration 1111 / 1225) loss: 1.725336
# (Iteration 1121 / 1225) loss: 1.913663
# (Iteration 1131 / 1225) loss: 1.797333
# (Iteration 1141 / 1225) loss: 1.839629
# (Iteration 1151 / 1225) loss: 1.824555
# (Iteration 1161 / 1225) loss: 1.759332
# (Iteration 1171 / 1225) loss: 1.745889
# (Iteration 1181 / 1225) loss: 1.787077
# (Iteration 1191 / 1225) loss: 1.763759
# (Iteration 1201 / 1225) loss: 1.737543
# (Iteration 1211 / 1225) loss: 1.736448
# (Iteration 1221 / 1225) loss: 1.705846
# (Epoch 5 / 5) train acc: 0.382000; val_acc: 0.363000
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.112000; val_acc: 0.105000
# (Iteration 11 / 1225) loss: 2.287068
# (Iteration 21 / 1225) loss: 2.252286
# (Iteration 31 / 1225) loss: 2.132803
# (Iteration 41 / 1225) loss: 2.070368
# (Iteration 51 / 1225) loss: 2.049129
# (Iteration 61 / 1225) loss: 2.010753
# (Iteration 71 / 1225) loss: 2.006430
# (Iteration 81 / 1225) loss: 1.989298
# (Iteration 91 / 1225) loss: 1.996353
# (Iteration 101 / 1225) loss: 1.959103
# (Iteration 111 / 1225) loss: 1.932863
# (Iteration 121 / 1225) loss: 1.902761
# (Iteration 131 / 1225) loss: 1.896614
# (Iteration 141 / 1225) loss: 1.904440
# (Iteration 151 / 1225) loss: 1.749783
# (Iteration 161 / 1225) loss: 1.900687
# (Iteration 171 / 1225) loss: 1.843922
# (Iteration 181 / 1225) loss: 1.935929
# (Iteration 191 / 1225) loss: 1.876450
# (Iteration 201 / 1225) loss: 1.831728
# (Iteration 211 / 1225) loss: 1.790177
# (Iteration 221 / 1225) loss: 1.816438
# (Iteration 231 / 1225) loss: 1.825231
# (Iteration 241 / 1225) loss: 1.802996
# (Epoch 1 / 5) train acc: 0.344000; val_acc: 0.357000
# (Iteration 251 / 1225) loss: 1.849194
# (Iteration 261 / 1225) loss: 1.646261
# (Iteration 271 / 1225) loss: 1.690743
# (Iteration 281 / 1225) loss: 1.791872
# (Iteration 291 / 1225) loss: 1.778847
# (Iteration 301 / 1225) loss: 1.703177
# (Iteration 311 / 1225) loss: 1.746623
# (Iteration 321 / 1225) loss: 1.675619
# (Iteration 331 / 1225) loss: 1.724031
# (Iteration 341 / 1225) loss: 1.687287
# (Iteration 351 / 1225) loss: 1.720101
# (Iteration 361 / 1225) loss: 1.722615
# (Iteration 371 / 1225) loss: 1.681363
# (Iteration 381 / 1225) loss: 1.645799
# (Iteration 391 / 1225) loss: 1.704051
# (Iteration 401 / 1225) loss: 1.715500
# (Iteration 411 / 1225) loss: 1.665530
# (Iteration 421 / 1225) loss: 1.556911
# (Iteration 431 / 1225) loss: 1.575297
# (Iteration 441 / 1225) loss: 1.632035
# (Iteration 451 / 1225) loss: 1.616319
# (Iteration 461 / 1225) loss: 1.521172
# (Iteration 471 / 1225) loss: 1.649423
# (Iteration 481 / 1225) loss: 1.542933
# (Epoch 2 / 5) train acc: 0.389000; val_acc: 0.409000
# (Iteration 491 / 1225) loss: 1.533538
# (Iteration 501 / 1225) loss: 1.545724
# (Iteration 511 / 1225) loss: 1.617349
# (Iteration 521 / 1225) loss: 1.615042
# (Iteration 531 / 1225) loss: 1.525153
# (Iteration 541 / 1225) loss: 1.630334
# (Iteration 551 / 1225) loss: 1.772125
# (Iteration 561 / 1225) loss: 1.537965
# (Iteration 571 / 1225) loss: 1.454950
# (Iteration 581 / 1225) loss: 1.620387
# (Iteration 591 / 1225) loss: 1.512819
# (Iteration 601 / 1225) loss: 1.605159
# (Iteration 611 / 1225) loss: 1.485622
# (Iteration 621 / 1225) loss: 1.651241
# (Iteration 631 / 1225) loss: 1.625501
# (Iteration 641 / 1225) loss: 1.568296
# (Iteration 651 / 1225) loss: 1.541147
# (Iteration 661 / 1225) loss: 1.467260
# (Iteration 671 / 1225) loss: 1.458239
# (Iteration 681 / 1225) loss: 1.685587
# (Iteration 691 / 1225) loss: 1.577545
# (Iteration 701 / 1225) loss: 1.536623
# (Iteration 711 / 1225) loss: 1.498148
# (Iteration 721 / 1225) loss: 1.443961
# (Iteration 731 / 1225) loss: 1.456583
# (Epoch 3 / 5) train acc: 0.452000; val_acc: 0.446000
# (Iteration 741 / 1225) loss: 1.554142
# (Iteration 751 / 1225) loss: 1.553306
# (Iteration 761 / 1225) loss: 1.557269
# (Iteration 771 / 1225) loss: 1.628554
# (Iteration 781 / 1225) loss: 1.374226
# (Iteration 791 / 1225) loss: 1.448008
# (Iteration 801 / 1225) loss: 1.401871
# (Iteration 811 / 1225) loss: 1.537126
# (Iteration 821 / 1225) loss: 1.626969
# (Iteration 831 / 1225) loss: 1.474547
# (Iteration 841 / 1225) loss: 1.460501
# (Iteration 851 / 1225) loss: 1.379919
# (Iteration 861 / 1225) loss: 1.287050
# (Iteration 871 / 1225) loss: 1.399989
# (Iteration 881 / 1225) loss: 1.432874
# (Iteration 891 / 1225) loss: 1.451497
# (Iteration 901 / 1225) loss: 1.377711
# (Iteration 911 / 1225) loss: 1.468210
# (Iteration 921 / 1225) loss: 1.563051
# (Iteration 931 / 1225) loss: 1.391090
# (Iteration 941 / 1225) loss: 1.422722
# (Iteration 951 / 1225) loss: 1.340410
# (Iteration 961 / 1225) loss: 1.506877
# (Iteration 971 / 1225) loss: 1.434935
# (Epoch 4 / 5) train acc: 0.479000; val_acc: 0.466000
# (Iteration 981 / 1225) loss: 1.366301
# (Iteration 991 / 1225) loss: 1.431596
# (Iteration 1001 / 1225) loss: 1.391711
# (Iteration 1011 / 1225) loss: 1.443715
# (Iteration 1021 / 1225) loss: 1.362917
# (Iteration 1031 / 1225) loss: 1.354165
# (Iteration 1041 / 1225) loss: 1.329385
# (Iteration 1051 / 1225) loss: 1.457007
# (Iteration 1061 / 1225) loss: 1.491926
# (Iteration 1071 / 1225) loss: 1.420066
# (Iteration 1081 / 1225) loss: 1.484238
# (Iteration 1091 / 1225) loss: 1.468681
# (Iteration 1101 / 1225) loss: 1.404177
# (Iteration 1111 / 1225) loss: 1.607603
# (Iteration 1121 / 1225) loss: 1.399456
# (Iteration 1131 / 1225) loss: 1.378255
# (Iteration 1141 / 1225) loss: 1.461869
# (Iteration 1151 / 1225) loss: 1.450018
# (Iteration 1161 / 1225) loss: 1.368209
# (Iteration 1171 / 1225) loss: 1.431325
# (Iteration 1181 / 1225) loss: 1.393722
# (Iteration 1191 / 1225) loss: 1.464678
# (Iteration 1201 / 1225) loss: 1.317075
# (Iteration 1211 / 1225) loss: 1.369425
# (Iteration 1221 / 1225) loss: 1.463555
# (Epoch 5 / 5) train acc: 0.525000; val_acc: 0.491000
# (Iteration 1 / 1225) loss: 2.302581
# (Epoch 0 / 5) train acc: 0.198000; val_acc: 0.197000
# (Iteration 11 / 1225) loss: 2.272770
# (Iteration 21 / 1225) loss: 2.144746
# (Iteration 31 / 1225) loss: 2.086299
# (Iteration 41 / 1225) loss: 2.024819
# (Iteration 51 / 1225) loss: 1.990553
# (Iteration 61 / 1225) loss: 2.016590
# (Iteration 71 / 1225) loss: 1.890469
# (Iteration 81 / 1225) loss: 1.926113
# (Iteration 91 / 1225) loss: 1.910196
# (Iteration 101 / 1225) loss: 1.949981
# (Iteration 111 / 1225) loss: 1.783337
# (Iteration 121 / 1225) loss: 1.703444
# (Iteration 131 / 1225) loss: 1.741380
# (Iteration 141 / 1225) loss: 1.733915
# (Iteration 151 / 1225) loss: 1.778590
# (Iteration 161 / 1225) loss: 1.806439
# (Iteration 171 / 1225) loss: 1.691713
# (Iteration 181 / 1225) loss: 1.717677
# (Iteration 191 / 1225) loss: 1.800838
# (Iteration 201 / 1225) loss: 1.728503
# (Iteration 211 / 1225) loss: 1.765382
# (Iteration 221 / 1225) loss: 1.663189
# (Iteration 231 / 1225) loss: 1.651600
# (Iteration 241 / 1225) loss: 1.661672
# (Epoch 1 / 5) train acc: 0.380000; val_acc: 0.385000
# (Iteration 251 / 1225) loss: 1.709662
# (Iteration 261 / 1225) loss: 1.628006
# (Iteration 271 / 1225) loss: 1.612365
# (Iteration 281 / 1225) loss: 1.695178
# (Iteration 291 / 1225) loss: 1.768837
# (Iteration 301 / 1225) loss: 1.668505
# (Iteration 311 / 1225) loss: 1.664073
# (Iteration 321 / 1225) loss: 1.611756
# (Iteration 331 / 1225) loss: 1.602109
# (Iteration 341 / 1225) loss: 1.527174
# (Iteration 351 / 1225) loss: 1.716230
# (Iteration 361 / 1225) loss: 1.659942
# (Iteration 371 / 1225) loss: 1.481129
# (Iteration 381 / 1225) loss: 1.518915
# (Iteration 391 / 1225) loss: 1.679918
# (Iteration 401 / 1225) loss: 1.637232
# (Iteration 411 / 1225) loss: 1.573152
# (Iteration 421 / 1225) loss: 1.529009
# (Iteration 431 / 1225) loss: 1.520681
# (Iteration 441 / 1225) loss: 1.495889
# (Iteration 451 / 1225) loss: 1.556999
# (Iteration 461 / 1225) loss: 1.472561
# (Iteration 471 / 1225) loss: 1.490421
# (Iteration 481 / 1225) loss: 1.549951
# (Epoch 2 / 5) train acc: 0.415000; val_acc: 0.461000
# (Iteration 491 / 1225) loss: 1.447907
# (Iteration 501 / 1225) loss: 1.542674
# (Iteration 511 / 1225) loss: 1.583484
# (Iteration 521 / 1225) loss: 1.551850
# (Iteration 531 / 1225) loss: 1.412841
# (Iteration 541 / 1225) loss: 1.572727
# (Iteration 551 / 1225) loss: 1.511593
# (Iteration 561 / 1225) loss: 1.586222
# (Iteration 571 / 1225) loss: 1.486697
# (Iteration 581 / 1225) loss: 1.470983
# (Iteration 591 / 1225) loss: 1.584790
# (Iteration 601 / 1225) loss: 1.578535
# (Iteration 611 / 1225) loss: 1.536226
# (Iteration 621 / 1225) loss: 1.508533
# (Iteration 631 / 1225) loss: 1.445207
# (Iteration 641 / 1225) loss: 1.493871
# (Iteration 651 / 1225) loss: 1.535334
# (Iteration 661 / 1225) loss: 1.397980
# (Iteration 671 / 1225) loss: 1.571937
# (Iteration 681 / 1225) loss: 1.512141
# (Iteration 691 / 1225) loss: 1.377795
# (Iteration 701 / 1225) loss: 1.638772
# (Iteration 711 / 1225) loss: 1.377656
# (Iteration 721 / 1225) loss: 1.402089
# (Iteration 731 / 1225) loss: 1.365661
# (Epoch 3 / 5) train acc: 0.492000; val_acc: 0.486000
# (Iteration 741 / 1225) loss: 1.442807
# (Iteration 751 / 1225) loss: 1.351334
# (Iteration 761 / 1225) loss: 1.337602
# (Iteration 771 / 1225) loss: 1.351046
# (Iteration 781 / 1225) loss: 1.373952
# (Iteration 791 / 1225) loss: 1.487711
# (Iteration 801 / 1225) loss: 1.450750
# (Iteration 811 / 1225) loss: 1.489800
# (Iteration 821 / 1225) loss: 1.391311
# (Iteration 831 / 1225) loss: 1.421561
# (Iteration 841 / 1225) loss: 1.525214
# (Iteration 851 / 1225) loss: 1.341834
# (Iteration 861 / 1225) loss: 1.387281
# (Iteration 871 / 1225) loss: 1.441119
# (Iteration 881 / 1225) loss: 1.444588
# (Iteration 891 / 1225) loss: 1.237254
# (Iteration 901 / 1225) loss: 1.350198
# (Iteration 911 / 1225) loss: 1.558691
# (Iteration 921 / 1225) loss: 1.331890
# (Iteration 931 / 1225) loss: 1.579053
# (Iteration 941 / 1225) loss: 1.390714
# (Iteration 951 / 1225) loss: 1.294318
# (Iteration 961 / 1225) loss: 1.412852
# (Iteration 971 / 1225) loss: 1.458116
# (Epoch 4 / 5) train acc: 0.538000; val_acc: 0.511000
# (Iteration 981 / 1225) loss: 1.392884
# (Iteration 991 / 1225) loss: 1.485219
# (Iteration 1001 / 1225) loss: 1.391178
# (Iteration 1011 / 1225) loss: 1.366180
# (Iteration 1021 / 1225) loss: 1.317606
# (Iteration 1031 / 1225) loss: 1.338451
# (Iteration 1041 / 1225) loss: 1.332329
# (Iteration 1051 / 1225) loss: 1.406975
# (Iteration 1061 / 1225) loss: 1.412436
# (Iteration 1071 / 1225) loss: 1.318378
# (Iteration 1081 / 1225) loss: 1.468159
# (Iteration 1091 / 1225) loss: 1.321497
# (Iteration 1101 / 1225) loss: 1.368842
# (Iteration 1111 / 1225) loss: 1.440156
# (Iteration 1121 / 1225) loss: 1.350306
# (Iteration 1131 / 1225) loss: 1.400094
# (Iteration 1141 / 1225) loss: 1.409923
# (Iteration 1151 / 1225) loss: 1.421821
# (Iteration 1161 / 1225) loss: 1.314937
# (Iteration 1171 / 1225) loss: 1.520933
# (Iteration 1181 / 1225) loss: 1.304254
# (Iteration 1191 / 1225) loss: 1.420105
# (Iteration 1201 / 1225) loss: 1.204765
# (Iteration 1211 / 1225) loss: 1.401194
# (Iteration 1221 / 1225) loss: 1.321855
# (Epoch 5 / 5) train acc: 0.509000; val_acc: 0.512000

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.512
# Test set accuracy:  0.487
